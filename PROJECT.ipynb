# %% [markdown]
# # From Print to Touch to AI: Reinterpreting the 1850 New Testament Through Accessibility and Generative AI

# %% [markdown]
# ## Context

# %% [markdown]
# ### Introduction

# %% [markdown]
# The bible is one of the most influential religious and cultural texts in human history. It is a collection of sacred writings central to Christianity, which includes teachings, narratives, poetry, and historical accounts that have shaped societies, moral values, literature, and art for centuries. The New Testament focuses on the life, teachings, death, and resurrection of Jesus Christ, as well as the development of early Christianity.

# %% [markdown]
# This project focuses on “The New Testament of Our Lord and Saviour Jesus Christ: Translated out of the Original Greek & with the Former Translations Diligently Compared & Revised”, published in 1850 by the American Bible Society. The American Bible Society is an organisation that has printed and distributed some 4 billion Bibles to date, and even in the 19th century played a key role in bringing religious texts to a wider audience. This book is particularly significant as it incorporated a format that allowed a wide range of readers, including those with visual disabilities, to read by touch through techniques such as embossing the text, prior to the widespread adoption of Braille. Therefore, this book is not only a religious text but also holds value as a cultural artefact illustrating the history of accessibility and inclusive reading practices.

# %% [markdown]
# In John 9:1–12, a man who had been blind from birth is depicted as a beggar, and Jesus’ disciples ask whether his blindness is due to his own sins or those of his parents. Jesus rejects this notion, replying instead that the man’s condition exists “so that God's works might be revealed in him” (Ridling, 1989, p. 2699). Like the story of the man healed by Jesus and restored to sight, this passage brings hope to people with visual disabilities. It is particularly significant in that it challenges conventional views of blindness and suffering. Rather than portraying blindness as a punishment, it presents the possibility of dignity, transformation, and new understanding. Therefore, this book is not only a religious text but also occupies an important place in the history of accessibility and inclusive reading practices.

# %% [markdown]
# ### Background Information

# %% [markdown]
# The American Bible Society (ABS) was founded in 1816 with the aim of making the Bible affordable and accessible throughout the United States and the world. The organisation combined religious, educational, and charitable purposes, striving to ensure that as many people as possible, regardless of their social background or geographical location, could read the Bible. Over time, the ABS grew into one of the world's largest Bible publishers, printing and distributing billions of Bibles in multiple languages and formats. During the Civil War, ABS produced the first pocket Bible for soldiers, bringing the light of the gospel to the front lines of the nation's darkest periods. Furthermore, ABS has contributed to a wide range of developments in literacy and accessibility. In 1835, they translated the world's first Braille Bible, enabling blind people to read the Bible for the first time (American Bible Society, 2026).

# %% [markdown]
# “The new testament of our lord and saviour Jesus Christ: translated out of the original Greek & with the former translations diligently compared & revised” (The new testament of our lord and saviour Jesus Christ) is an edition of the New Testament published in New York in 1850 by the American Bible Society. The text is a translation from the Greek into English, dating from the 17th century. The phrase ‘with the former translations diligently compared & revised’ indicates that the translators placed great importance on the accuracy of the text and its continuity with earlier Bible translations. This edition is of particular significance for its materials and accessibility features. Unlike the standard printed Bibles of the time, this Bible was printed using raised lettering, allowing those who were blind or partially sighted to read it by touch. Rather than the Braille developed by Louis Braille, it adopted the Boston Line Type system, invented in 1835 by Samuel Gridley Howe, the first headmaster of the Perkins School for the Blind, since Louis's Braille had not been invented and announced.

# %% [markdown]
# Boston Line Type adopted a simplified Roman alphabet with angular, triangular shapes, based on the principle that straight lines and acute angles are easier to distinguish by touch than curves. Furthermore, to improve tactile readability, capital letters were omitted. During the 19th century, the Boston Line Type became one of the most widely used tactile reading systems in the United States and remained in widespread use for several decades until Braille became widely adopted. The manufacturing process for embossed books was not only technically demanding but also costly. Printing required assembling and securing metal plates moulded into the shapes of raised characters, which were then pressed onto thick paper. A close inspection reveals faint rectangular marks around the characters, traces of this mechanical printing process. The high cost of specialised printing equipment was likely one reason why embossed tactile books remained relatively limited in circulation, despite their importance in terms of accessibility.

# %% [markdown]
# One reason why linear embossing systems such as the Boston Line Type gained popularity was that they were designed to be readable not only by blind individuals but also by sighted people. This reflects the 19th-century view that tactile reading systems should not be designed solely with the needs of blind people in mind, but should also be visually recognisable to sighted people (Old Starbridge Village, 2024). Consequently, this New Testament is an important historical example of early accessible publishing practices, demonstrating how religious texts contributed to the development of inclusive reading technologies prior to the standardisation of Braille.

# %%
from IPython.display import Image
Image('sampl.jpg')

# %% [markdown]
# left: Sample of Braille

# %% [markdown]
# right: Sample of Boston Line Type

# %% [markdown]
# More example Boston Line Type: [Boston Line Type
# by Perkins School for the Blind Archive](https://www.flickr.com/photos/perkinsarchive/albums/72157635886962895/)

# %% [markdown]
# ## Objectives

# %% [markdown]
# The aim of this project is to investigate, through an analysis of "The new testament of our lord and saviour Jesus Christ", the extent to which modern generative AI and image recognition technologies can interpret and preserve historically accessible reading systems. This edition is historically significant not only as a religious text but also as a testament to accessible 19th century publishing. This is because it was produced using Boston Line Type, an embossed typeface that served as a tactile reading system developed prior to the widespread adoption of Braille. In particular, this project will verify whether AI systems can accurately recognise and interpret the embossed characters of the Boston Line Type from digital images of the text, and convert the recognised content into modern Braille. In doing so, we will explore the relationship between historical tactile communication systems and modern machine interpretation technologies, whilst examining how accessibility practices have evolved from embossed printing to the interpretation of digital formats.

# %% [markdown]
# Furthermore, this project aims to critically examine the collaborative role of humans and AI in the interpretation and translation process. Rather than positioning AI as an autonomous interpretation tool, we conceptualise it as a computational tool that supports human-led archival interpretation through pattern recognition, image analysis and text generation. Human involvement is indispensable in the selection of materials, historical contextualisation, the verification of AI-generated outputs, and the correction of inaccuracies in transcription and translation. By evaluating both the capabilities and limitations of AI systems when processing historical tactile texts, this project aims to assess whether AI can make a meaningful contribution to the preservation and reinterpretation of historical accessibility technologies within cultural heritage collections.

# %% [markdown]
# ## Methodology

# %% [markdown]
# ### Initial Steps and Research

# %% [markdown]
# In order to achieve the objectives of this project and explore how accessibility for the blind and AI can be combined through human creativity and AI, I first needed to examine the materials in the University of Glasgow’s archives and take photographs of them. I took several photographs and transferred them to my computer. I then selected the AI to be used.

# %% [markdown]
# ### What kind of AI Tools

# %% [markdown]
# * [Chat GPT](https://chatgpt.com/#) : A conversational AI developed by OpenAI; a general-purpose AI assistant capable of handling a wide range of tasks, including text generation, summarisation, translation, brainstorming and programming assistance.
# * [Copilot](https://copilot.microsoft.com/) : An AI assistant provided by Microsoft; a tool that assists with tasks through search, text generation, summarisation and integration with Office products, such as Word and Excel.
# * [Enter](https://enter.pro/features/ai-agent-builder?utm_source=google&utm_medium=cpc&utm_campaign=23833156979&utm_device=c&utm_network=x&utm_channel=agency&gclid=Cj0KCQjw2YDQBhD_ARIsAE1qeSeckaGaVFoyvwkkvDSqARUwvsA4owJSQ196RS3vy-co4H6ZeCFspMsaAk9QEALw_wcB&gad_source=1&gad_campaignid=23837683870&gbraid=0AAAABCVKq3Exhdk3byoTKCpHI8B2vf4RV&gclid=Cj0KCQjw2YDQBhD_ARIsAE1qeSeckaGaVFoyvwkkvDSqARUwvsA4owJSQ196RS3vy-co4H6ZeCFspMsaAk9QEALw_wcB) : A platform for creating AI agents without coding, serving as a development tool that simplifies the implementation of business automation and chatbot development.
# * [Tasklet](https://tasklet.ai/?utm_content=AI_Evangelists&gad_source=1&gad_campaignid=23557819092&gbraid=0AAAAAov_um-L9Ondy2GRIhqSfxnwTmG4o&gclid=Cj0KCQjw2YDQBhD_ARIsAE1qeSeDkwcolGIr30tBNl2TFB0NjJyBDFkvQLEFaP6qTG2jMsRG-fcN20kaAl0LEALw_wcB) : An AI tool designed to support task management and business process automation, specialising in streamlining workflows and automating task execution.
# * [Perplexity](https://www.perplexity.ai/) : An AI search engine-style assistant characterised by providing direct, summarised answers to questions based on information from the internet, whilst also citing the sources.
# Perplexity AI official website.

# %% [markdown]
# ### My Design

# %% [markdown]
# In my design, I conducted an experiment to verify how four different generative AI models recognise and analyse images of sections of the Bible and generate appropriate Braille representations. Initially, I had planned to use photographs of the entire section (A_pic.jpg), but due to low image contrast, the AI was unable to recognise the text accurately. Consequently, I ultimately used images covering only half of the page (B_pic.jpg).
#
# In this study, generative AI was utilised for the following purposes:
#
# * Recognition and analysis of textual information within images
# * Verification of the accuracy of the conversion to Braille
# * Comparison of output results between the various AI models
#
# In the experiment, the same image was input into each AI generation site, and the responses and Braille output generated for the specified font and search criteria were observed and compared. This enabled an analysis of each generative AI model’s image recognition capabilities, text comprehension abilities, and the accuracy of Braille generation.
# The prompt used is as follows with picture (B_pic.jpg).

# %%
Image('A_pic.jpg')

# %%
from IPython.display import Image
Image('B_pic.jpg')

# %% [markdown]
# The prompt used is as follows with picture (B_pic.jpg).
#
# "Please identify and accurately transcribe the text shown in the image, then convert the transcribed text into Braille. Ensure that the Braille output is clear, correctly formatted, and faithful to the original text."
#
# I will also be using this website for translation: [BrailleTranslator.org](https://www.brailletranslator.org/)

# %% [markdown]
# ## A detailed and critical analysis of four AI models

# %% [markdown]
# **ChatGPT**
#
# [Transcribed Text]
#
# chapter 11.
# 1 & it came to pass, when Jesus had made an end of commanding his twelve disciples, he departed thence to teach & to preach in their cities.
# 2 Now when John had heard in the prison the works of Christ, he sent two of his disciples,
# 3 & said unto him, art thou he that should come, or do we look for another?
# 4 Jesus answered & said unto them, go & shew John again those things which ye do hear & see:
# 5 the blind receive their sight, & the lame walk, the lepers are cleansed, & the deaf hear, the dead are raised up, & the poor have the gospel preached to them.
# 6 & blessed is he, whosoever shall not be offended in me.
# 7 & as they departed, Jesus began to say unto the multitudes concern
#
# [Braille]
#
# ⠉⠓⠁⠏⠞⠑⠗ ⠼⠁⠼⠁⠲
#
# ⠼⠁ ⠯ ⠊⠞ ⠉⠁⠍⠑ ⠞⠕ ⠏⠁⠎⠎⠂ ⠺⠓⠑⠝ ⠚⠑⠎⠥⠎ ⠓⠁⠙ ⠍⠁⠙⠑ ⠁⠝ ⠑⠝⠙ ⠕⠋ ⠉⠕⠍⠍⠁⠝⠙⠊⠝⠛ ⠓⠊⠎ ⠞⠺⠑⠇⠧⠑ ⠙⠊⠎⠉⠊⠏⠇⠑⠎⠂ ⠓⠑ ⠙⠑⠏⠁⠗⠞⠑⠙ ⠞⠓⠑⠝⠉⠑ ⠞⠕ ⠞⠑⠁⠉⠓ ⠯ ⠞⠕ ⠏⠗⠑⠁⠉⠓ ⠊⠝ ⠞⠓⠑⠊⠗ ⠉⠊⠞⠊⠑⠎⠲
#
# ⠼⠃ ⠝⠕⠺ ⠺⠓⠑⠝ ⠚⠕⠓⠝ ⠓⠁⠙ ⠓⠑⠁⠗⠙ ⠊⠝ ⠞⠓⠑ ⠏⠗⠊⠎⠕⠝ ⠞⠓⠑ ⠺⠕⠗⠅⠎ ⠕⠋ ⠉⠓⠗⠊⠎⠞⠂ ⠓⠑ ⠎⠑⠝⠞ ⠞⠺⠕ ⠕⠋ ⠓⠊⠎ ⠙⠊⠎⠉⠊⠏⠇⠑⠎⠂
#
# ⠼⠉ ⠯ ⠎⠁⠊⠙ ⠥⠝⠞⠕ ⠓⠊⠍⠂ ⠁⠗⠞ ⠞⠓⠕⠥ ⠓⠑ ⠞⠓⠁⠞ ⠎⠓⠕⠥⠇⠙ ⠉⠕⠍⠑⠂ ⠕⠗ ⠙⠕ ⠺⠑ ⠇⠕⠕⠅ ⠋⠕⠗ ⠁⠝⠕⠞⠓⠑⠗⠦
#
# ⠼⠙ ⠚⠑⠎⠥⠎ ⠁⠝⠎⠺⠑⠗⠑⠙ ⠯ ⠎⠁⠊⠙ ⠥⠝⠞⠕ ⠞⠓⠑⠍⠂ ⠛⠕ ⠯ ⠎⠓⠑⠺ ⠚⠕⠓⠝ ⠁⠛⠁⠊⠝ ⠞⠓⠕⠎⠑ ⠞⠓⠊⠝⠛⠎ ⠺⠓⠊⠉⠓ ⠽⠑ ⠙⠕ ⠓⠑⠁⠗ ⠯ ⠎⠑⠑⠒
#
# ⠼⠑ ⠞⠓⠑ ⠃⠇⠊⠝⠙ ⠗⠑⠉⠑⠊⠧⠑ ⠞⠓⠑⠊⠗ ⠎⠊⠛⠓⠞⠂ ⠯ ⠞⠓⠑ ⠇⠁⠍⠑ ⠺⠁⠇⠅⠂ ⠞⠓⠑ ⠇⠑⠏⠑⠗⠎ ⠁⠗⠑ ⠉⠇⠑⠁⠝⠎⠑⠙⠂ ⠯ ⠞⠓⠑ ⠙⠑⠁⠋ ⠓⠑⠁⠗⠂ ⠞⠓⠑ ⠙⠑⠁⠙ ⠁⠗⠑ ⠗⠁⠊⠎⠑⠙ ⠥⠏⠂ ⠯ ⠞⠓⠑ ⠏⠕⠕⠗ ⠓⠁⠧⠑ ⠞⠓⠑ ⠛⠕⠎⠏⠑⠇ ⠏⠗⠑⠁⠉⠓⠑⠙ ⠞⠕ ⠞⠓⠑⠍⠲
#
# ⠼⠋ ⠯ ⠃⠇⠑⠎⠎⠑⠙ ⠊⠎ ⠓⠑⠂ ⠺⠓⠕⠎⠕⠑⠧⠑⠗ ⠎⠓⠁⠇⠇ ⠝⠕⠞ ⠃⠑ ⠕⠋⠋⠑⠝⠙⠑⠙ ⠊⠝ ⠍⠑⠲
#
# ⠼⠛ ⠯ ⠁⠎ ⠞⠓⠑⠽ ⠙⠑⠏⠁⠗⠞⠑⠙⠂ ⠚⠑⠎⠥⠎ ⠃⠑⠛⠁⠝ ⠞⠕ ⠎⠁⠽ ⠥⠝⠞⠕ ⠞⠓⠑ ⠍⠥⠇⠞⠊⠞⠥⠙⠑⠎ ⠉⠕⠝⠉⠑⠗⠝
#
# [Translation]
#
# #a & it came to pass1 when jesus had made an end of commanding his twelve disciples1 he departed thence to teach & to preach in their cities4
#
# #b now when john had heard in the prison the works of christ1 he sent two of his disciples1
#
# #c & said unto him1 art thou he that should come1 or do we look for another8
#
# #d jesus answered & said unto them1 go & shew john again those things which ye do hear & see3
#
# #e the blind receive their sight1 & the lame walk1 the lepers are cleansed1 & the deaf hear1 the dead are raised up1 & the poor have the gospel preached to them4
#
# #f & blessed is he1 whosoever shall not be offended in me4
#
# #g & as they departed1 jesus began to say unto the multitudes concern

# %% [markdown]
# **Copilot**
#
# [Transcribed Text]
#
# chapter 11. & it came to pass when Jesus had made an end of com- manding his twelve disciples, he departed thence to teach & to preach in their cities. 2 now when John had heard in the prison the works of Christ, he sent two of his disciples, & said unto him, art thou he that should come, or do we look for another? 4 Jesus answered & said unto them, Go & shew John again those things which ye do hear & see: the blind receive their sight, & the lame walk, the lepers are cleansed, & the deaf hear, the dead are raised up, & the poor have the gospel preached to them. 6 & blessed is he whosoever shall not be offended in me. 7 as they departed, Jesus began to say unto the multitudes concern-
#
# [Braille]
#
# ⠉⠓⠁⠏⠞⠻ ⠁⠁⠁⠂
# ⠯ ⠊⠞ ⠉⠁⠍⠑ ⠞⠕ ⠏⠁⠎⠎ ⠺⠓⠑⠝ ⠚⠑⠎⠥⠎ ⠓⠁⠙ ⠍⠁⠙⠑ ⠁⠝ ⠑⠝⠙ ⠕⠋ ⠉⠕⠍-
# ⠍⠁⠝⠙⠊⠝⠛ ⠓⠊⠎ ⠞⠺⠑⠇⠧⠑ ⠙⠊⠎⠉⠊⠏⠇⠑⠎⠂ ⠓⠑ ⠙⠑⠏⠁⠗⠞⠑⠙ ⠞⠓⠻⠝⠉⠑ ⠞⠕ ⠞⠑⠁⠉⠓ ⠯
# ⠞⠕ ⠏⠗⠑⠁⠉⠓ ⠊⠝ ⠞⠓⠻⠊⠗ ⠉⠊⠞⠊⠑⠎⠲
# ⠼⠃ ⠝⠕⠺ ⠺⠓⠑⠝ ⠚⠕⠓⠝ ⠓⠁⠙ ⠓⠑⠁⠗⠙ ⠊⠝
# ⠞⠓⠑ ⠏⠗⠊⠎⠕⠝ ⠞⠓⠑ ⠺⠕⠗⠅⠎ ⠕⠋ ⠉⠓⠗⠊⠎⠞⠂ ⠓⠑ ⠎⠑⠝⠞ ⠞⠺⠕ ⠕⠋ ⠓⠊⠎ ⠙⠊⠎⠉⠊⠏⠇⠑⠎⠂
# ⠯ ⠎⠁⠊⠙ ⠥⠝⠞⠕ ⠓⠊⠍⠂ ⠁⠗⠞ ⠞⠓⠕⠥ ⠓⠑ ⠞⠓⠁⠞ ⠎⠓⠕⠥⠇⠙ ⠉⠕⠍⠑⠂ ⠕⠗ ⠙⠕ ⠺⠑
# ⠇⠕⠕⠅ ⠋⠕⠗ ⠁⠝⠕⠞⠓⠻⠦ ⠼⠙ ⠚⠑⠎⠥⠎ ⠁⠝⠎⠺⠻⠑⠙ ⠯ ⠎⠁⠊⠙ ⠥⠝⠞⠕ ⠞⠓⠑⠍⠂
# ⠛⠕ ⠯ ⠎⠓⠑⠺ ⠚⠕⠓⠝ ⠁⠛⠁⠊⠝ ⠞⠓⠕⠎⠑ ⠞⠓⠊⠝⠛⠎ ⠺⠓⠊⠉⠓ ⠽⠑ ⠙⠕ ⠓⠑⠁⠗ ⠯ ⠎⠑⠑⠒
# ⠞⠓⠑ ⠃⠇⠊⠝⠙ ⠗⠑⠉⠑⠊⠧⠑ ⠞⠓⠻⠊⠗ ⠎⠊⠛⠓⠞⠂ ⠯ ⠞⠓⠑ ⠇⠁⠍⠑ ⠺⠁⠇⠅⠂ ⠞⠓⠑ ⠇⠑⠏⠻⠎
# ⠁⠗⠑ ⠉⠇⠑⠁⠝⠎⠑⠙⠂ ⠯ ⠞⠓⠑ ⠙⠑⠁⠋ ⠓⠑⠁⠗⠂ ⠞⠓⠑ ⠙⠑⠁⠙ ⠁⠗⠑ ⠗⠁⠊⠎⠑⠙ ⠥⠏⠂ ⠯
# ⠞⠓⠑ ⠏⠕⠕⠗ ⠓⠁⠧⠑ ⠞⠓⠑ ⠛⠕⠎⠏⠑⠇ ⠏⠗⠑⠁⠉⠓⠑⠙ ⠞⠕ ⠞⠓⠑⠍⠲ ⠼⠋ ⠯ ⠃⠇⠑⠎⠎⠑⠙
# ⠊⠎ ⠓⠑ ⠺⠓⠕⠎⠕⠑⠧⠻ ⠎⠓⠁⠇⠇ ⠝⠕⠞ ⠃⠑ ⠕⠋⠋⠑⠝⠙⠑⠙ ⠊⠝ ⠍⠑⠲ ⠼⠛ ⠁⠎ ⠞⠓⠑⠽
# ⠙⠑⠏⠁⠗⠞⠑⠙⠂ ⠚⠑⠎⠥⠎ ⠃⠑⠛⠁⠝ ⠞⠕ ⠎⠁⠽ ⠥⠝⠞⠕ ⠞⠓⠑ ⠍⠥⠇⠞⠊⠞⠥⠙⠑⠎ ⠉⠕⠝⠉⠻⠝-
#
# [Translation]
#
#
# chapt} aaa1
# & it came to pass when jesus had made an end of com-
# manding his twelve disciples1 he departed th}nce to teach &
# to preach in th}ir cities4
# #b now when john had heard in
# the prison the works of christ1 he sent two of his disciples1
# & said unto him1 art thou he that should come1 or do we
# look for anoth}8 #d jesus answ}ed & said unto them1
# go & shew john again those things which ye do hear & see3
# the blind receive th}ir sight1 & the lame walk1 the lep}s
# are cleansed1 & the deaf hear1 the dead are raised up1 &
# the poor have the gospel preached to them4 #f & blessed
# is he whosoev} shall not be offended in me4 #g as they
# departed1 jesus began to say unto the multitudes conc}n-

# %% [markdown]
# **Tasklet**
#
# [Transcribed Text]
#
# Chapter 11. And it came to pass when Jesus had made an end of commanding his twelve disciples, he departed thence to teach & preach in their cities. 2 Now when John had heard in the prison the works of Christ, he sent two of his disciples, & said unto him, art thou he that should come, or do we look for another? 4 Jesus answered & said unto them, Go & shew John again those things which ye do hear & see: the blind receive their sight, & the lame walk, the lepers are cleansed, & the deaf hear, the dead are raised up, & the poor have the gospel preached to them. 6 & blessed is whosoever shall not be offended in me. 7 & as they departed, Jesus began to say unto the multitudes concern-
#
# [Braille]
#
# ⠠⠉⠓⠁⠏⠞⠑⠗⠀⠼⠁⠼⠁⠲
#
# ⠠⠁⠝⠙⠀⠊⠞⠀⠉⠁⠍⠑⠀⠞⠕⠀⠏⠁⠎⠎⠀⠺⠓⠑⠝⠀⠠⠚⠑⠎⠥⠎⠀⠓⠁⠙⠀⠍⠁⠙⠑⠀⠁⠝⠀⠑⠝⠙⠀⠕⠋⠀
# ⠉⠕⠍⠍⠁⠝⠙⠊⠝⠛⠀⠓⠊⠎⠀⠞⠺⠑⠇⠧⠑⠀⠙⠊⠎⠉⠊⠏⠇⠑⠎⠂⠀⠓⠑⠀⠙⠑⠏⠁⠗⠞⠑⠙⠀⠞⠓⠑⠝⠉⠑⠀
# ⠞⠕⠀⠞⠑⠁⠉⠓⠀⠯⠀⠏⠗⠑⠁⠉⠓⠀⠊⠝⠀⠞⠓⠑⠊⠗⠀⠉⠊⠞⠊⠑⠎⠲⠀⠼⠃⠀⠠⠝⠕⠺⠀⠺⠓⠑⠝⠀⠠⠚⠕⠓⠝⠀
# ⠓⠁⠙⠀⠓⠑⠁⠗⠙⠀⠊⠝⠀⠞⠓⠑⠀⠏⠗⠊⠎⠕⠝⠀⠞⠓⠑⠀⠺⠕⠗⠅⠎⠀⠕⠋⠀⠠⠉⠓⠗⠊⠎⠞⠂⠀⠓⠑⠀⠎⠑⠝⠞⠀
# ⠞⠺⠕⠀⠕⠋⠀⠓⠊⠎⠀⠙⠊⠎⠉⠊⠏⠇⠑⠎⠂⠀⠯⠀⠎⠁⠊⠙⠀⠥⠝⠞⠕⠀⠓⠊⠍⠂⠀⠁⠗⠞⠀⠞⠓⠕⠥⠀⠓⠑⠀⠞⠓⠁⠞⠀
# ⠎⠓⠕⠥⠇⠙⠀⠉⠕⠍⠑⠂⠀⠕⠗⠀⠙⠕⠀⠺⠑⠀⠇⠕⠕⠅⠀⠋⠕⠗⠀⠁⠝⠕⠞⠓⠑⠗⠦⠀⠼⠙⠀⠠⠚⠑⠎⠥⠎⠀⠁⠝⠎⠺⠑⠗⠑⠙⠀
# ⠯⠀⠎⠁⠊⠙⠀⠥⠝⠞⠕⠀⠞⠓⠑⠍⠂⠀⠠⠛⠕⠀⠯⠀⠎⠓⠑⠺⠀⠠⠚⠕⠓⠝⠀⠁⠛⠁⠊⠝⠀⠞⠓⠕⠎⠑⠀⠞⠓⠊⠝⠛⠎⠀
# ⠺⠓⠊⠉⠓⠀⠽⠑⠀⠙⠕⠀⠓⠑⠁⠗⠀⠯⠀⠎⠑⠑⠒⠀⠞⠓⠑⠀⠃⠇⠊⠝⠙⠀⠗⠑⠉⠑⠊⠧⠑⠀⠞⠓⠑⠊⠗⠀⠎⠊⠛⠓⠞⠂⠀
# ⠯⠀⠞⠓⠑⠀⠇⠁⠍⠑⠀⠺⠁⠇⠅⠂⠀⠞⠓⠑⠀⠇⠑⠏⠑⠗⠎⠀⠁⠗⠑⠀⠉⠇⠑⠁⠝⠎⠑⠙⠂⠀⠯⠀⠞⠓⠑⠀⠙⠑⠁⠋⠀
# ⠓⠑⠁⠗⠂⠀⠞⠓⠑⠀⠙⠑⠁⠙⠀⠁⠗⠑⠀⠗⠁⠊⠎⠑⠙⠀⠥⠏⠂⠀⠯⠀⠞⠓⠑⠀⠏⠕⠕⠗⠀⠓⠁⠧⠑⠀⠞⠓⠑⠀⠛⠕⠎⠏⠑⠇⠀
# ⠏⠗⠑⠁⠉⠓⠑⠙⠀⠞⠕⠀⠞⠓⠑⠍⠲⠀⠼⠋⠀⠯⠀⠃⠇⠑⠎⠎⠑⠙⠀⠊⠎⠀⠺⠓⠕⠎⠕⠑⠧⠑⠗⠀⠎⠓⠁⠇⠇⠀⠝⠕⠞⠀
# ⠃⠑⠀⠕⠋⠋⠑⠝⠙⠑⠙⠀⠊⠝⠀⠍⠑⠲⠀⠼⠛⠀⠯⠀⠁⠎⠀⠞⠓⠑⠽⠀⠙⠑⠏⠁⠗⠞⠑⠙⠂⠀⠠⠚⠑⠎⠥⠎⠀⠃⠑⠛⠁⠝⠀
# ⠞⠕⠀⠎⠁⠽⠀⠥⠝⠞⠕⠀⠞⠓⠑⠀⠍⠥⠇⠞⠊⠞⠥⠙⠑⠎⠀⠉⠕⠝⠉⠑⠗⠝⠤
#
# [Translation]
#
# ,chapter #a#a4
#
# ,and it came to pass when ,jesus had made an end of
# commanding his twelve disciples1 he departed thence
# to teach & preach in their cities4 #b ,now when ,john
# had heard in the prison the works of ,christ1 he sent
# two of his disciples1 & said unto him1 art thou he that
# should come1 or do we look for another8 #d ,jesus answered
# & said unto them1 ,go & shew ,john again those things
# which ye do hear & see3 the blind receive their sight1
# & the lame walk1 the lepers are cleansed1 & the deaf
# hear1 the dead are raised up1 & the poor have the gospel
# preached to them4 #f & blessed is whosoever shall not
# be offended in me4 #g & as they departed1 ,jesus began
# to say unto the multitudes concern-

# %% [markdown]
# **Perplexity**
#
# [Transcribed Text]
#
# chapter 11.
# And it came to pass, when Jesus had made an end of commanding his twelve disciples, he departed thence to teach and preach in their cities.
# 2 Now when John had heard in the prison the works of Christ, he sent two of his disciples,
# 3 And said unto him, Art thou he that should come, or do we look for another?
# 4 Jesus answered and said unto them,
# Go and shew John again those things which ye do hear and see:
# 5 The blind receive their sight, and the lame walk, the lepers are cleansed, and the deaf hear, the dead are raised up, and the poor have the gospel preached to them.
# 6 And blessed is he, whosoever shall not be offended in me.
# 7 And as they departed, Jesus began to say unto the multitudes concerning
#
# [Braille]
#
# ⠉⠓⠁⠏⠞⠑⠗ ⠼⠁⠁⠲
# ⠠⠁⠝⠙ ⠊⠞ ⠉⠁⠍⠑ ⠞⠕ ⠏⠁⠎⠎⠂ ⠺⠓⠑⠝ ⠠⠚⠑⠎⠥⠎ ⠓⠁⠙ ⠍⠁⠙⠑ ⠁⠝ ⠑⠝⠙ ⠕⠋ ⠉⠕⠍⠍⠁⠝⠙⠊⠝⠛ ⠓⠊⠎ ⠞⠺⠑⠧⠑ ⠙⠊⠎⠉⠊⠏⠇⠑⠎⠂ ⠓⠑ ⠙⠑⠏⠁⠗⠞⠑⠙ ⠞⠓⠑⠝⠉⠑ ⠞⠕ ⠞⠑⠁⠉⠓ ⠁⠝⠙ ⠏⠗⠑⠁⠉⠓ ⠊⠝ ⠞⠓⠑⠊⠗ ⠉⠊⠞⠊⠑⠎⠲
# ⠼⠃ ⠠⠝⠕⠺ ⠺⠓⠑⠝ ⠠⠚⠕⠓⠝ ⠓⠁⠙ ⠓⠑⠁⠗⠙ ⠊⠝ ⠞⠓⠑ ⠏⠗⠊⠎⠕⠝ ⠞⠓⠑ ⠺⠕⠗⠅⠎ ⠕⠋ ⠠⠉⠓⠗⠊⠎⠞⠂ ⠓⠑ ⠎⠑⠝⠞ ⠞⠺⠕ ⠕⠋ ⠓⠊⠎ ⠙⠊⠎⠉⠊⠏⠇⠑⠎⠲
# ⠼⠉ ⠠⠁⠝⠙ ⠎⠁⠊⠙ ⠥⠝⠞⠕ ⠓⠊⠍⠂ ⠠⠁⠗⠞ ⠞⠓⠕⠥ ⠓⠑ ⠞⠓⠁⠞ ⠎⠓⠕⠥⠇⠙ ⠉⠕⠍⠑⠂ ⠕⠗ ⠙⠕ ⠺⠑ ⠇⠕⠕⠅ ⠋⠕⠗ ⠁⠝⠕⠞⠓⠑⠗⠦
# ⠼⠙ ⠠⠚⠑⠎⠥⠎ ⠁⠝⠎⠺⠑⠗⠑⠙ ⠁⠝⠙ ⠎⠁⠊⠙ ⠥⠝⠞⠕ ⠞⠓⠑⠍⠂
# ⠠⠛⠕ ⠁⠝⠙ ⠎⠓⠑⠺ ⠠⠚⠕⠓⠝ ⠁⠛⠁⠊⠝ ⠞⠓⠕⠎⠑ ⠞⠓⠊⠝⠛⠎ ⠺⠓⠊⠉⠓ ⠽⠑ ⠙⠕ ⠓⠑⠁⠗ ⠁⠝⠙ ⠎⠑⠑⠒
# ⠼⠑ ⠠⠞⠓⠑ ⠃⠇⠊⠝⠙ ⠗⠑⠉⠑⠊⠧⠑ ⠞⠓⠑⠊⠗ ⠎⠊⠛⠓⠞⠂ ⠁⠝⠙ ⠞⠓⠑ ⠇⠁⠍⠑ ⠺⠁⠇⠅⠂ ⠞⠓⠑ ⠇⠑⠏⠑⠗⠎ ⠁⠗⠑ ⠉⠇⠑⠁⠝⠎⠑⠙⠂ ⠁⠝⠙ ⠞⠓⠑ ⠙⠑⠁⠋ ⠓⠑⠁⠗⠂ ⠞⠓⠑ ⠙⠑⠁⠙ ⠁⠗⠑ ⠗⠁⠊⠎⠑⠙ ⠥⠏⠂ ⠁⠝⠙ ⠞⠓⠑ ⠏⠕⠕⠗ ⠓⠁⠧⠑ ⠞⠓⠑ ⠛⠕⠎⠏⠑⠇ ⠏⠗⠑⠁⠉⠓⠑⠙ ⠞⠕ ⠞⠓⠑⠍⠲
# ⠼⠋ ⠠⠁⠝⠙ ⠃⠇⠑⠎⠎⠑⠙ ⠊⠎ ⠓⠑⠂ ⠺⠓⠕⠎⠕⠑⠧⠑⠗ ⠎⠓⠁⠇⠇ ⠝⠕⠞ ⠃⠑ ⠕⠋⠋⠑⠝⠙⠑⠙ ⠊⠝ ⠍⠑⠲
# ⠼⠛ ⠠⠁⠝⠙ ⠁⠎ ⠞⠓⠑⠽ ⠙⠑⠏⠁⠗⠞⠑⠙⠂ ⠠⠚⠑⠎⠥⠎ ⠃⠑⠛⠁⠝ ⠞⠕ ⠎⠁⠽ ⠥⠝⠞⠕ ⠞⠓⠑ ⠍⠥⠇⠞⠊⠞⠥⠙⠑⠎ ⠉⠕⠝⠉⠑⠗⠝⠊⠝⠛
#
# [Translation]
#
# chapter #aa4
# ,and it came to pass1 when ,jesus had made an end of commanding his tweve disciples1 he departed thence to teach and preach in their cities4
#
# #) b ,now when ,john had heard in the prison the works of ,christ1 he sent two of his disciples4
#
# #) c ,and said unto him1 ,art thou he that should come1 or do we look for another8
#
# #) d ,jesus answered and said unto them1
# ,go and shew ,john again those things which ye do hear and see3
#
# #) e ,the blind receive their sight1 and the lame walk1 the lepers are cleansed1 and the deaf hear1 the dead are raised up1 and the poor have the gospel preached to them4
#
# #) f ,and blessed is he1 whosoever shall not be offended in me4
#
# #) g ,and as they departed1 ,jesus began to say unto the multitudes concerning

# %% [markdown]
# ## Presentation
